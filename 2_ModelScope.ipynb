# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyasaravana/VideoGen/blob/main/2_ModelScope.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model Scope

# %% [markdown]
# ### Generate Text 2 Video based on Model Scope model

# %% [markdown]
# ### 1. Setup the Environment

# %% [markdown]
# 1.1 Install all the prerequisites

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install diffusers transformers accelerate torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 73.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 70.3 MB/s eta 0:00:00
# ...

# %%
#pip install git+https://github.com/huggingface/diffusers transformers accelerate

# %% [markdown]
# 1.2 Set up the OS environment for the diffusers model from Modelscope

# %%
import atexit
import subprocess
import os
#os.system("winget install --id Git.Git -e --source winget")
#os.system("winget install --id=Python.Python.3.10  -e")
os.system("pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118")
os.system("git lfs install")
os.system("git clone https://huggingface.co/damo-vilab/text-to-video-ms-1.7b")
os.system("pip install diffusers transformers accelerate torch")
os.system("cls")
# Out:
# 32512

# %%
# !pip install numpy==1.19.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 17.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for numpy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects

# %% [markdown]
# ## 2. Run the Text2Video model. Generate the video based on the prompt

# %%
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video
from google.colab import files

pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b-legacy", torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()

prompt = "Spiderman is surfing"
video_frames = pipe(prompt, num_inference_steps=25).frames
video_path = export_to_video(video_frames)

files.download(video_path)
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %% [markdown]
# ### 2.1 Example 1: generate the video based on the text prompt

# %%
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video

pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()

prompt = "Spiderman is surfing"
video_frames = pipe(prompt, num_inference_steps=25).frames
video_path = export_to_video(video_frames)
video_name = video_path.replace('/tmp/', '')
print('Name:', video_name)
torch.cuda.empty_cache()
from google.colab import files
files.download(video_path)
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Name: tmpnt2e11o5.mp4

# %% [markdown]
# ### 2.2 Example 2: generate the video based on the text prompt

# %%
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video

pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()

prompt = "A girl is walking on the grass"

video_frames = pipe(prompt, num_inference_steps=25).frames
video_path = export_to_video(video_frames)
video_name = video_path.replace('/tmp/', '')
print('Name:', video_name)
torch.cuda.empty_cache()

files.download(video_path)
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Name: tmp3d68pv8o.mp4

# %% [markdown]
# ### 2.3 Example 3: generate the video based on the text prompt

# %%
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video

pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()

prompt = "A lone traveler found solace in the forgotten pages of an old book"
video_frames = pipe(prompt, num_inference_steps=25).frames
video_path = export_to_video(video_frames)
video_name = video_path.replace('/tmp/', '')
print('Name:', video_name)
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Name: tmpcfa32gfi.mp4

# %% [markdown]
# ### 2.4 Interactive Video generation based on the model scope model

# %%
import atexit
import torch
import subprocess
import os

def exitfunction():
	torch.cuda.empty_cache()

atexit.register(exitfunction)

def main():
	from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
	from diffusers.utils import export_to_video
	pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
	pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
	pipe.enable_model_cpu_offload()
	# prompts for an input to text to video
	promptvariable = input()
	prompt = promptvariable
	# if video does not render, lower num_frames or inference_steps until video renders
	video_frames = pipe(prompt, num_inference_steps=150, num_frames=50).frames
	video_path = export_to_video(video_frames)
	print("'Video rendered with' + num_inference_steps + 'inference steps, and ' + num_frames 'frames.'")
	# print output
	print("---------------------------------------------------------------------------------------------------")
	print("| Your video has been saved at" + video_path +"|")
	print("---------------------------------------------------------------------------------------------------")
	torch.cuda.empty_cache()
	os.system("start " + video_path)
	open(video_path)
	print("---------------------------------------------------------------------------------------------------")
	print("|                       Would you like to generate another video? (y/n)                           |")
	print("---------------------------------------------------------------------------------------------------")
	n = "n"
	y = "y"
	generate_more = input()
	if generate_more == y:
		main()
	if generate_more == n:
		exit()
	else:
		exit()

main()
# Out:
# ---------------------------------------------------------------------------------------------------
# |					    ~Loading AI~		  	                 |
# ---------------------------------------------------------------------------------------------------
# ...
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# ...
#
#
#
#
#
#
# ---------------------------------------------------------------------------------------------------
# |              Custom script by https://www.linkedin.com/in/joshua-roberts-bb167a211/             |
# ---------------------------------------------------------------------------------------------------
# |
# |
# ---------------------------------------------------------------------------------------------------
# |                         To generate higher inference steps or frame count,                      |
# |                   edit the num_inference_steps and num_frames parameters in run.py              |
# ...
